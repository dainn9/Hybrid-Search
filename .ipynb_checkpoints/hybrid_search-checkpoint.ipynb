# %%
from rank_bm25 import BM25Okapi
from sentence_transformers import SentenceTransformer
from pymilvus import connections, Collection
import pandas as pd
from underthesea import ner
import re
import unicodedata

# %% [markdown]
# # Kết nối Milvus

# %%
connections.connect("default", host="localhost", port="19530")
collection = Collection("hotels_collection_mpnet_base_v2")

# %% [markdown]
# # Load dữ liệu

# %%
df = pd.read_csv("dataset.csv")
docs = df["Descriptions"].fillna("").tolist()

# %% [markdown]
# # BM25

# %%
tokenized_docs = [d.lower().split() for d in docs]
bm25 = BM25Okapi(tokenized_docs)

# %% [markdown]
# # SBERT

# %%
model = SentenceTransformer("paraphrase-multilingual-mpnet-base-v2")

# %%
def detect_city(query):
    cities = {
        "hồ chí minh": "Hồ Chí Minh",
        "tp hồ chí minh": "Hồ Chí Minh",
        "tp.hcm": "Hồ Chí Minh",
        "sài gòn": "Hồ Chí Minh",
        "hà nội": "Hà Nội",
        "đà nẵng": "Đà Nẵng",
        "phú quốc": "Phú Quốc",
        "nha trang": "Nha Trang",
        "hội an": "Hội An",
        "đà lạt": "Đà Lạt",
        "sa pa": "Sa Pa",
        "sapa": "Sa Pa",
        "huế": "Huế",
        "vũng tàu": "Vũng Tàu"
    }
    query_lower = query.lower()
    
    # Rule-based
    for k, v in cities.items():
        if k in query_lower:
            return v
    
    # NER-based
    for word, _, _, tag in ner(query):
        if tag.endswith("LOC"):
            print(f'Địa danh nhận dạng: {word}')
            return word.title()
    
    return None

def prepare_query(query):
    city = detect_city(query)
    if city:
        semantic_query = query.lower().replace(city.lower(), "").strip()
        expr = f'Location like "%{city}%"'
    else:
        semantic_query = query
        expr = ""
    
    return semantic_query, expr

def clean_text_for_query(text):
    if not isinstance(text, str):
        return ""

    text = unicodedata.normalize('NFC', text)
    text = text.lower()

    text = re.sub(r"[^\w\s/\-]", " ", text)

    text = re.sub(r"\s+", " ", text).strip()

    return text

# %%
def hybrid_search(query, alpha=1):
    tokenized_query = query.lower().split()
    bm25_scores = bm25.get_scores(tokenized_query)

    semantic_query, expr = prepare_query(query)
    semantic_query = clean_text_for_query(semantic_query)
    
    query_emb = model.encode([query], normalize_embeddings=True)
    search_params = {"metric_type": "COSINE", "params": {"M": 8, "efConstruction": 64}}

    results = collection.search(
        data=query_emb,
        anns_field="TextForEmbedding",
        param=search_params,
        limit=10,
        expr=expr,
        output_fields=["HotelID"]
    )

    milvus_hits = []
    for hits in results:
        for hit in hits:
            milvus_hits.append((hit.entity.get("HotelID"), 1 - hit.distance))
    milvus_df = pd.DataFrame(milvus_hits, columns=["HotelID", "semantic_score"])

    bm25_df = df[["HotelID"]].copy()
    bm25_df["bm25_score"] = bm25_scores

    merged = pd.merge(bm25_df, milvus_df, on="HotelID", how="inner")
    merged["final_score"] = alpha * merged["semantic_score"] + (1 - alpha) * merged["bm25_score"]
    merged = merged.sort_values(by="final_score", ascending=False).head(10)

    for _, r in merged.iterrows():
        hotel = df[df["HotelID"] == r["HotelID"]].iloc[0]
        print(f"🏨 {hotel['Name Hotel']} (Score: {r['final_score']:.4f})")
        print(f"   {hotel['Descriptions']}\n")

# %% [markdown]
# # Test

# %%
query = "homestay có hồ bơi gần biển Hà nội"
hybrid_search(query)
# Out:
# 🏨 The Euphoria Hanoi (Score: 0.3301)
#    Tọa lạc tại thành phố Hà Nội, cách Hồ Tây 1,8 km, The Euphoria Hanoi có tầm nhìn ra hồ bơi, WiFi miễn phí và chỗ đỗ xe riêng miễn phí. Mỗi căn tại đây đều có khu vực bếp ăn với lò vi sóng cùng tủ lạnh, két an toàn, TV truyền hình vệ tinh màn hình phẳng, tiện nghi ủi, bàn làm việc và khu vực ghế ngồi đi kèm ghế sofa. Tất cả các căn được bố trí phòng tắm riêng với vòi xịt/chậu rửa vệ sinh, dép đi trong phòng, máy sấy tóc và đồ vệ sinh cá nhân miễn phí. Khách sạn căn hộ này có sân hiên. The Euphoria Hanoi có dịch vụ giặt là cũng như các tiện nghi phục vụ doanh nhân như máy fax và máy photocopy. Chỗ nghỉ cung cấp cả dịch vụ cho thuê xe đạp lẫn xe hơi. The Euphoria Hanoi nằm cách Đền Quán Thánh 2,5 km và Lăng Chủ tịch Hồ Chí Minh 3,1 km. Sân bay gần nhất là sân bay quốc tế Nội Bài, nằm trong bán kính 17 km từ khách sạn căn hộ này.
#
# 🏨 Aira Boutique Hanoi Hotel & Spa (Score: 0.3274)
#    Nằm trong Khu Phố Pháp yên bình, Aira Boutique Hanoi Hotel & Spa có hồ bơi ngoài trời, phòng tập thể dục và khu vườn. Khách sạn này nằm trong bán kính 700 m từ Nhà Thờ Lớn, Bảo tàng Lịch sử Quân sự Việt Nam, Cột cờ Hà Nội và Hoàng thành Thăng Long. Chỗ nghỉ cung cấp WiFi miễn phí. Du khách đi bộ 15 phút là có thể đến các điểm tham quan nổi tiếng của thành phố Hà Nội như Hồ Hoàn Kiếm, Bảo tàng Mỹ thuật Việt Nam, Văn Miếu - Quốc Tử Giám và Chợ Đồng Xuân. Sân bay gần nhất là sân bay quốc tế Nội Bài, cách Aira Boutique Hanoi Hotel & Spa 35 phút lái xe. Nổi bật với phong cách thuộc địa, phòng nghỉ tại khách sạn được trang bị TV thông minh, bàn làm việc và phòng tắm riêng với đồ vệ sinh cá nhân miễn phí. Hầu hết các phòng đều có ban công trong khi một số phòng nhìn ra các di tích mang tính biểu tượng của Hà Nội. Nhà hàng tại Aira Boutique Hanoi Hotel & Spa chuyên về ẩm thực Việt Nam, Nhật Bản và Quốc tế. Du khách có thể thưởng thức bữa sáng tự chọn hàng ngày. Nhân viên tại quầy lễ tân 24 giờ có thể tư vấn về các hoạt động trong khu vực cho du khách.
#
# 🏨 Entire Cosy Apartments May Homestay Hanoi (Score: 0.3230)
ng và ga trải giường. Mỗi phòng đều được bố trí ấm đun nước và tủ lạnh. Một số phòng có ban công trong khi các phòng còn lại nhìn ra hồ nước.  Văn Miếu - Quốc Tử Giám và Đền Quán Thánh đều nằm trong bán kính 5 km từ The Lakeview - West Lake Lotus Apartments. Sân bay gần nhất là sân bay quốc tế Nội Bài, cách đó 16 km, và chỗ nghỉ cung cấp dịch vụ đưa đón sân bay với một khoản phụ phí.
#
# 🏨 Hanoi Paon Hotel & Spa (Score: 0.2872)
#    Hanoi Paon Hotel & Spa nằm trong Khu Phố Cổ của thành phố Hà Nội, cách Hồ Hoàn Kiếm và Sông Hồng 500 m. Chỗ nghỉ này có hồ bơi ngoài trời với hệ thống lọc muối điện phân. Tất cả phòng nghỉ không hút thuốc, trang nhã tại đây đều có WiFi miễn phí, máy điều hòa, TV màn hình LED và minibar. Trong phòng được trang bị bàn trang điểm, két an toàn cá nhân và tủ để quần áo. Phòng tắm riêng đi kèm bồn tắm/vòi sen, máy sấy tóc và đồ vệ sinh cá nhân miễn phí. Hầu hết các phòng được bố trí cửa sổ hoặc ban công riêng nhìn ra quang cảnh quận Hoàn Kiếm. Du khách có thể thư giãn với đồ uống tại quầy bar nhìn ra toàn cảnh dòng sông và thành phố. Hồ bơi nằm trên tầng thượng. Du khách cũng có thể sử dụng phòng tập thể dục miễn phí hoặc tận hưởng những phút giây thư giãn tại spa với một loạt liệu pháp mát-xa để lựa chọn. Nhân viên giao tiếp bằng tiếng Việt, tiếng Anh và tiếng Pháp tại quầy lễ tân 24 giờ có thể hỗ trợ khách lên kế hoạch cho kỳ nghỉ. Bàn đặt tour cung cấp cho khách những thông tin hữu ích về các tour tham quan. Chỗ nghỉ cũng có dịch thụ thu đổi ngoại tệ và dịch vụ cho thuê xe hơi. Sân bay gần nhất là sân bay quốc tế Nội Bài, nằm trong bán kính 21 km từ Hanoi Paon Hotel & Spa.
#
# 🏨 VietHome-Doorstep to Hoan Kiem Lake (Score: 0.2821)
#    VietHome-Doorstep to Hoan Kiem Lake cung cấp phòng nghỉ gắn máy điều hòa với truyền hình cáp màn hình phẳng ở quận Hoàn Kiếm của thành phố Hà Nội. Nhà khách này nằm cách Hồ Hoàn Kiếm khoảng 400 m và Nhà Thờ Lớn 500 m. Chỗ nghỉ có WiFi miễn phí và tầm nhìn ra quang cảnh thành phố. Phòng nghỉ tại nhà khách có khu vực ghế ngồi và phòng tắm riêng đi kèm chậu rửa vệ sinh (bidet), máy sấy tóc cùng đồ vệ sinh cá nhân miễn phí. Bàn làm việc và ấm đun nước cũng được trang bị trong phòng. Các điểm tham quan nổi tiếng gần VietHome-Doorstep to Hoan Kiem Lake bao gồm trung tâm thương mại Tràng Tiền Plaza, Nhà Hát Lớn Hà Nội và Nhà hát múa rối nước Thăng Long. Sân bay gần nhất là sân bay quốc tế Nội Bài, nằm trong bán kính 27 km từ chỗ nghỉ này.
