# %%
from rank_bm25 import BM25Okapi
from sentence_transformers import SentenceTransformer
from pymilvus import connections, Collection
import pandas as pd
from underthesea import ner
import re
import unicodedata
import string
import numpy as np

# %% [markdown]
# # Kết nối Milvus

# %%
connections.connect("default", host="localhost", port="19530")
collection = Collection("hotels_collection_mpnet_base_v2")

# %% [markdown]
# # SBERT - BM25

# %%
def removed_puncts(input_string):
    return input_string.translate(str.maketrans('','',string.punctuation)).lower()

# %%
# Lấy toàn bộ corpus trước, batch để tránh OOM
batch_size = 500
offset = 0
all_descriptions = []

while True:
    batch = collection.query(
        expr="",  # không filter
        offset=offset,
        limit=batch_size,
        output_fields=["HotelID", "Description"],
    )
    
    if not batch:  # hết data
        break
    
    all_descriptions.extend([row["Description"] for row in batch])
    offset += batch_size

# %%
clearn_corpus = []
for doc in all_descriptions:
    clean_doc = removed_puncts(doc)
    clearn_corpus.append(clean_doc)

# %%
tokenized_clean_corpus = []
for doc in clearn_corpus:
    doc = doc.split()
    tokenized_clean_corpus.append(doc)

# %%
bm25_corpus_full = BM25Okapi(tokenized_clean_corpus)

# %%
model = SentenceTransformer("paraphrase-multilingual-mpnet-base-v2")

# %%
def detect_city(query):
    cities = {
        "hồ chí minh": "Hồ Chí Minh",
        "tp hồ chí minh": "Hồ Chí Minh",
        "tp.hcm": "Hồ Chí Minh",
        "sài gòn": "Hồ Chí Minh",
        "hà nội": "Hà Nội",
        "đà nẵng": "Đà Nẵng",
        "phú quốc": "Phú Quốc",
        "nha trang": "Nha Trang",
        "hội an": "Hội An",
        "đà lạt": "Đà Lạt",
        "sa pa": "Sa Pa",
        "sapa": "Sa Pa",
        "huế": "Huế",
        "vũng tàu": "Vũng Tàu"
    }
    query_lower = query.lower()
    
    # Rule-based
    for k, v in cities.items():
        if k in query_lower:
            print(f'Địa danh nhận dạng: {v}')
            return v
    
    # NER-based
    for word, _, _, tag in ner(query):
        if tag.endswith("LOC"):
            # if word.title() in df["Location"].unique():
            expr = f'Location == "{word}"'
            results = collection.query(expr=expr, output_fields=["Location"])
            if results:
                print(f'Địa danh nhận dạng: {word}')
                return word.title()
    
    return None

def clean_text_for_query(text):
    if not isinstance(text, str):
        return ""

    text = unicodedata.normalize('NFC', text)
    text = text.lower()

    text = re.sub(r"[^\w\s/\-]", " ", text)
    text = re.sub(r"\s+", " ", text).strip()

    return text

# %%
def prepare_query(query):
    city = detect_city(query)
    tokenized_query = removed_puncts(query).split(" ")
    expr = ""
    bm25_scores = []
    
    if city:
        expr = f'Location like "%{city.lower()}%"'
        
        results = collection.query(
            expr=expr,
            output_fields=["HotelID", "Description"],
        )
        
        if results:
            # Lọc theo city
            filtered_docs = [r['Description'] for r in results]
            tokenized_filtered = [d.lower().split() for d in filtered_docs]
            bm25_local = BM25Okapi(tokenized_filtered)
            bm25_scores = bm25_local.get_scores(tokenized_query)   

    # Nếu không có city hoặc expr filter không trả về gì
    else:
        bm25_scores = bm25_corpus_full.get_scores(tokenized_query)

    # Normalize an toàn
    bm25_scores = np.array(bm25_scores)
    if bm25_scores.max() != bm25_scores.min():
        bm25_scores = (bm25_scores - bm25_scores.min()) / (bm25_scores.max() - bm25_scores.min())
    else:
        bm25_scores = [0] * len(bm25_scores)

    semantic_query = query.lower().replace(city.lower(), "").strip() if city else query.lower()
    
    return semantic_query, expr, bm25_scores

# %%
def hybrid_search(query, alpha=0.5, top_k=20):
    
    semantic_query, expr, bm25_scores = prepare_query(query)
    semantic_query = clean_text_for_query(semantic_query)
    
    query_emb = model.encode([semantic_query], normalize_embeddings=True)
    search_params = {"metric_type": "COSINE", "params": {"M": 8, "efConstruction": 64}}

    results = collection.search(
        data=query_emb,
        anns_field="TextForEmbedding",
        param=search_params,
        limit=top_k,
        expr=expr,
        output_fields=["HotelID", "Description", "NameHotel", "Location"]
    )

    milvus_hits = []
    for hits in results:
        for idx, hit in enumerate(hits):
            bm25_score = bm25_scores[idx] if idx < len(bm25_scores) else 0
            milvus_hits.append({
                "HotelID": hit.entity.get("HotelID"),
                "Name Hotel": hit.entity.get("NameHotel"),
                "Descriptions": hit.entity.get("Description"),
                "semantic_score": hit.distance,
                "bm25_score": bm25_score,
                "location" : hit.entity.get("Location"),
            })
            

    for h in milvus_hits:
        h["final_score"] = alpha * h["semantic_score"] + (1 - alpha) * h["bm25_score"]

    # Sắp xếp theo final score
    milvus_hits = sorted(milvus_hits, key=lambda x: x["final_score"], reverse=True)[:top_k]
        
    ids = [str(h['HotelID']) for h in milvus_hits]
    print("HotelID list:",",".join(ids))
    print("=" * 80)

    # In kết quả
    for h in milvus_hits:
        print(f"{h['Name Hotel']} (HotelId: {h['HotelID']}) (Score: {h['final_score']:.4f}) (Semantic: {h['semantic_score']:.4f}) (BM25: {h['bm25_score']:.4f}) (Location: {h['location']})")
        print(f"{h['Descriptions']}\n")
        # (HotelId: 3937) (Score: 0.2988) (Semantic: 0.8713) (BM25: 0.2988) (Location: đà nẵng)

# %%
# query = "Resort lãng mạn cho cặp đôi ở Đà Nẵng"
# query = "Resort gần biển yên tĩnh"
# query = "Khách sạn cho gia đình có trẻ em"
query = "khách sạn gần biển"
hybrid_search(query)
# Out:
# HotelID list: 342,1074
# ================================================================================
# codi sea hotel travel (HotelId: 342) (Score: 0.6628) (Semantic: 0.8688) (BM25: 0.4567) (Location: đà nẵng)
# tọa lạc tại thành phố đà nẵng, cách bãi biển mỹ khê 300 m, codi sea hotel travel có dịch vụ tiền sảnh, phòng nghỉ không gây dị ứng, sảnh khách chung, wifi miễn phí trong toàn bộ khuôn viên và khu vườn. khách sạn 2 sao này có dịch vụ phòng và bàn đặt tour. nơi đây cung cấp dịch vụ lễ tân 24 giờ, bếp chung và dịch vụ thu đổi ngoại tệ cho khách. tất cả phòng nghỉ tại codi sea hotel travel rooms đều được trang bị máy điều hòa, tv truyền hình vệ tinh màn hình phẳng, tủ lạnh, ấm đun nước, vòi xịt chậu rửa vệ sinh, dép, bàn làm việc, phòng tắm riêng và tủ để quần áo. một số phòng có sân trong và tầm nhìn ra quang cảnh biển. các phòng đi kèm ga trải giường và khăn tắm. chỗ nghỉ phục vụ bữa sáng à la carte hoặc bữa sáng kiểu á. codi sea hotel travel có sân hiên. đi xe đạp là hoạt động được ưa chuộng trong khu vực và du khách có thể thuê xe đạp xe hơi tại khách sạn. codi sea hotel travel nằm cách bãi biển bắc mỹ an 2,4 km và cầu khóa tình yêu 2,1 km. sân bay gần nhất là sân bay quốc tế đà nẵng, cách đó 6 km, và chỗ nghỉ cung cấp dịch vụ đưa đón sân bay với một khoản phụ phí.
#
# may hotel (HotelId: 1074) (Score: 0.6321) (Semantic: 0.8621) (BM25: 0.4021) (Location: đà nẵng)
# tọa lạc tại thành phố đà nẵng, cách bãi biển mỹ khê 300 m, may hotel cung cấp chỗ nghỉ bên bờ biển với nhiều tiện nghi như xe đạp cho khách sử dụng miễn phí và sân hiên. khách sạn 2 sao này có dịch vụ tiền sảnh, bàn đặt tour, lễ tân 24 giờ, dịch vụ đưa đón sân bay, dịch vụ phòng và wifi miễn phí trong toàn bộ khuôn viên. phòng nghỉ tại đây được trang bị máy điều hòa, tv truyền hình cáp màn hình phẳng, minibar, ấm đun nước, vòi xịt chậu rửa vệ sinh, dép và bàn làm việc. tất cả các phòng đều có phòng tắm riêng, máy sấy tóc và ga trải giường. bãi biển bắc mỹ an nằm trong bán kính 2,3 km từ khách sạn trong khi cầu khóa tình yêu cách đó 2 km. sân bay gần nhất là sân bay quốc tế đà nẵng, cách may hotel 6 km.

# %% [markdown]
# # Test

# %%
# query = "Resort lãng mạn cho cặp đôi ở Đà Nẵng"
# query = "Resort gần biển yên tĩnh"
# query = "Khách sạn cho gia đình có trẻ em"
query = "khách sạn gần biển"
hybrid_search(query)
# Out:
# HotelID list: 342,1074,3496,3937,2969,570,549,2099,658,1089,3038,631,1876,131,1151,3033,474,3324,1062,3667
# ================================================================================
# codi sea hotel travel (HotelId: 342) (Score: 0.0000) (Semantic: 0.8688) (BM25: 0.0000) (Location: đà nẵng)
# tọa lạc tại thành phố đà nẵng, cách bãi biển mỹ khê 300 m, codi sea hotel travel có dịch vụ tiền sảnh, phòng nghỉ không gây dị ứng, sảnh khách chung, wifi miễn phí trong toàn bộ khuôn viên và khu vườn. khách sạn 2 sao này có dịch vụ phòng và bàn đặt tour. nơi đây cung cấp dịch vụ lễ tân 24 giờ, bếp chung và dịch vụ thu đổi ngoại tệ cho khách. tất cả phòng nghỉ tại codi sea hotel travel rooms đều được trang bị máy điều hòa, tv truyền hình vệ tinh màn hình phẳng, tủ lạnh, ấm đun nước, vòi xịt chậu rửa vệ sinh, dép, bàn làm việc, phòng tắm riêng và tủ để quần áo. một số phòng có sân trong và tầm nhìn ra quang cảnh biển. các phòng đi kèm ga trải giường và khăn tắm. chỗ nghỉ phục vụ bữa sáng à la carte hoặc bữa sáng kiểu á. codi sea hotel travel có sân hiên. đi xe đạp là hoạt động được ưa chuộng trong khu vực và du khách có thể thuê xe đạp xe hơi tại khách sạn. codi sea hotel travel nằm cách bãi biển bắc mỹ an 2,4 km và cầu khóa tình yêu 2,1 km. sân bay gần nhất là sân bay quốc tế đà nẵng, cách đó 6 km, và chỗ nghỉ cung cấp dịch vụ đưa đón sân bay với một khoản phụ phí.
#
# ocean haven hotel (HotelId: 2969) (Score: 0.0000) (Semantic: 0.8590) (BM25: 0.0000) (Location: đà nẵng)
# nằm dọc theo bãi biển mỹ khê - phạm văn đồng và cách khoảng 5 phút đi bộ từ cầu rồng, ocean haven hotel là một khách sạn nhìn ra biển với các phòng nghỉ đầy phong cách đi kèm tầm nhìn ngoạn mục ra các bãi biển cát trắng cũng như dãy núi xung quanh cùng đại dương. với quầy lễ tân 24 giờ, nơi nghỉ có trung tâm dịch vụ doanh nhân và chỗ đỗ xe miễn phí trong khuôn viên. wi-fi miễn phí được cung cấp tại các khu vực chung khách sạn nằm trong bán kính chỉ 1,7 km từ cầu sông hàn và 2,5 km từ bảo tàng chăm. du khách đi 3,6 km là đến bãi biển mỹ an nổi tiếng trong khi sân bay phú bài cách đó trong khoảng 68 km lái xe. dịch vụ đưa đón và vận chuyển sân bay có thể được sắp xếp kèm theo phụ phí. các phòng nghỉ máy lạnh tại đây được bài trí trang nhã và có sàn lát gỗ, tủ quần áo, truyền hình cáp màn hình phẳng cũng như khu vực tiếp khách. minibar và ấm đun nước điện cũng có trong phòng. phòng tắm riêng được trang bị tiện nghi vòi sen, bồn tắm, dép và máy sấy tóc. khách nghỉ tại ocean haven hotel có thể thuê xe đạp xe hơi để khám phá khu vực và ghé vào các điểm tham quan gần đó. nhân viên thân thiện tại đây có thể hỗ trợ khách với các dịch vụ thu đổi ngoại tệ, giữ hành lý, giặt là và sắp xếp tour du lịch. nơi nghỉ này có nhà hàng phục vụ tuyển chọn các món ăn ngon của việt nam và phương tây. du khách cũng có thể được thưởng thức đồ uống sau bữa ăn.
#
# nam hotel residences (HotelId: 570) (Score: 0.0000) (Semantic: 0.8549) (BM25: 0.0000) (Location: đà nẵng)
# tọa lạc tại vị trí lý tưởng ở khu bãi biển mỹ khê thuộc thành phố đà nẵng, nam hotel residences nằm cách bãi biển mỹ khê chưa đầy 1 km, bãi biển bắc mỹ an 2,9 km và cầu sông hàn 1,3 km. chỗ nghỉ này có các phòng gia đình và hồ bơi ngoài trời. nơi đây cung cấp dịch vụ phòng, sảnh khách chung và dịch vụ thu đổi ngoại tệ cho khách. phòng nghỉ tại khách sạn được bố trí máy điều hòa, khu vực ghế ngồi, tv truyền hình cáp màn hình phẳng, két an toàn và phòng tắm riêng với vòi sen, áo choàng tắm cùng dép. wifi được cung cấp miễn phí cho tất cả các khách trong khi một số phòng còn có ban công. tất cả các phòng đều được trang bị bàn làm việc và ấm đun nước. khách được thoải mái sử dụng phòng xông hơi khô tại nam hotel residences. chỗ nghỉ cung cấp chỗ đỗ xe riêng miễn phí, dịch vụ văn phòng và dịch vụ lễ tân 24 giờ. cầu khóa tình yêu nằm trong bán kính 1,5 km từ chỗ nghỉ trong khi trung tâm thương mại indochina riverside cách đó 1,9 km. sân bay gần nhất là sân bay quốc tế đà nẵng, cách nam hotel residences 6 km, và chỗ nghỉ cung cấp dịch vụ đưa đón sân bay với một khoản phụ phí.
#
# sea sand hotel (HotelId: 549) (Score: 0.0000) (Semantic: 0.8530) (BM25: 0.0000) (Location: đà nẵng)
# tọa lạc ở thành phố đà nẵng, nằm trong bán kính 200 m từ bãi biển mỹ khê và 3,5 km từ cầu tàu tình yêu, sea sand hotel cung cấp chỗ nghỉ với sân hiên cũng như chỗ đỗ xe riêng miễn phí cho khách lái xe. trong số các tiện nghi của khách sạn này có lễ tân 24 giờ, dịch vụ phòng và wifi miễn phí trong toàn bộ khuôn viên. chỗ nghỉ không gây dị ứng và nằm cách công viên châu á 3,8 km. tất cả phòng nghỉ của khách sạn đều được bố trí máy điều hòa, khu vực ghế ngồi, truyền hình vệ tinh màn hình phẳng, bếp, khu vực ăn uống và phòng tắm riêng với máy sấy tóc, chậu rửa vệ sinh bidet cùng vòi sen. các phòng cũng có bàn làm việc và ấm đun nước. sea sand hotel nằm trong bán kính 4,2 km từ bảo tàng chăm và 5 km từ cầu sông hàn. sân bay gần nhất là sân bay quốc tế đà nẵng, cách chỗ nghỉ 5 km.
#
# khách sạn 178 trần phú (HotelId: 2099) (Score: 0.0000) (Semantic: 0.8530) (BM25: 0.0000) (Location: vũng tàu)
# tọa lạc tại thành phố vũng tàu, cách bạch dinh 3,5 km, khách sạn 178 trần phú cung cấp chỗ nghỉ bên bờ biển với nhiều tiện nghi như sảnh khách chung, vườn và khu vực bãi biển riêng. chỗ nghỉ này có dịch vụ phòng, tiện nghi bbq, lễ tân 24 giờ và bếp chung cho khách sử dụng. phòng nghỉ tại khách sạn được trang bị tủ để quần áo, tv màn hình phẳng, phòng tắm riêng, ga trải giường và khăn tắm. tất cả các phòng đều có tủ lạnh. khách sạn 178 trần phú có sân hiên tắm nắng. tượng chúa kitô vua nằm cách chỗ nghỉ 7 km trong khi mũi nghinh phong cách đó 8 km. sân bay gần nhất là sân bay quốc tế tân sơn nhất, nằm trong bán kính 111 km từ khách sạn 178 trần phú.
#
# sea beach hotel (HotelId: 658) (Score: 0.0000) (Semantic: 0.8525) (BM25: 0.0000) (Location: vũng tàu)
# tọa lạc ở thành phố vũng tàu, cách bãi sau chưa đến 1 km, sea beach hotel cung cấp chỗ nghỉ với wifi miễn phí và chỗ đỗ xe riêng miễn phí. chỗ nghỉ này nằm trong bán kính 2,2 km từ mũi nghinh phong, 3 km từ bạch dinh và 4,3 km từ ngọn hải đăng vũng tàu. chỗ nghỉ cung cấp dịch vụ phòng, dịch vụ tiền sảnh và phòng giữ hành lý cho khách. tất cả phòng nghỉ tại khách sạn đều được trang bị máy điều hòa, tv truyền hình cáp màn hình phẳng, tủ lạnh, ấm đun nước, vòi sen, dép và bàn làm việc. một số phòng có ban công và tầm nhìn ra quang cảnh núi non. các phòng được bố trí phòng tắm riêng và tủ để quần áo. các điểm tham quan nổi tiếng gần sea beach hotel bao gồm bãi dứa, bãi trước và tượng chúa kitô vua. sân bay gần nhất là sân bay quốc tế tân sơn nhất, nằm trong bán kính 108 km từ chỗ nghỉ.
phòng tắm chung. các phòng được bố trí tủ để quần áo, phòng tắm riêng, máy sấy tóc và ga trải giường. beach hotel có hồ bơi trong nhà. cầu khóa tình yêu nằm cách chỗ nghỉ 3 km trong khi bảo tàng chăm cách đó 3,7 km. sân bay gần nhất là sân bay quốc tế đà nẵng, nằm trong bán kính 7 km từ beach hotel, và chỗ nghỉ cung cấp dịch vụ đưa đón sân bay với một khoản phụ phí.
#
# phuong nam hotel (HotelId: 3033) (Score: 0.0000) (Semantic: 0.8383) (BM25: 0.0000) (Location: vũng tàu)
# tọa lạc tại thành phố vũng tàu, cách bãi dứa vài bước chân, phuong nam hotel cung cấp chỗ nghỉ bên bờ biển với nhiều tiện nghi như sảnh khách chung và sân hiên. trong số các tiện nghi tại chỗ nghỉ có lễ tân 24 giờ, dịch vụ phòng và wifi miễn phí trong toàn bộ khuôn viên. khách sạn cung cấp các phòng gia đình. tất cả phòng nghỉ tại khách sạn đều có tv màn hình phẳng, máy điều hòa và phòng tắm riêng với vòi sen cùng dép. một số phòng được bố trí khu vực ghế ngồi. các phòng được trang bị tủ để quần áo và ấm đun nước. các điểm tham quan nổi tiếng gần phuong nam hotel bao gồm bãi sau, bãi trước và tượng chúa kitô vua. sân bay gần nhất là sân bay quốc tế tân sơn nhất, nằm trong bán kính 72 km từ chỗ nghỉ.
#
# raon apartment and hotel (HotelId: 474) (Score: 0.0000) (Semantic: 0.8354) (BM25: 0.0000) (Location: đà nẵng)
# raon apartment and hotel tọa lạc bên bờ biển thành phố đà nẵng, cách bãi biển mỹ khê 700 m và cầu sông hàn 1,9 km. trong số các tiện nghi của chỗ nghỉ này có dịch vụ tiền sảnh, bàn đặt tour và wifi miễn phí trong toàn bộ khuôn viên. nơi đây cung cấp dịch vụ lễ tân 24 giờ, dịch vụ phòng và dịch vụ thu đổi ngoại tệ cho khách. tất cả phòng nghỉ tại đây được trang bị máy điều hòa, tv truyền hình vệ tinh màn hình phẳng, tủ lạnh, ấm đun nước, vòi sen, dép và bàn làm việc. mỗi phòng đều có phòng tắm riêng, máy sấy tóc và ga trải giường. khu vực này nổi tiếng với hoạt động đi bộ đường dài và du khách cũng có thể thuê xe hơi tại khách sạn. raon apartment and hotel nằm trong bán kính 2,4 km từ cầu khóa tình yêu và 2,8 km từ trung tâm thương mại indochina riverside. sân bay gần nhất là sân bay quốc tế đà nẵng, cách đó 7 km, và chỗ nghỉ cung cấp dịch vụ đưa đón sân bay với một khoản phụ phí.
#
# regalia nha trang (HotelId: 3324) (Score: 0.0000) (Semantic: 0.8325) (BM25: 0.0000) (Location: nha trang)
# tọa lạc dọc theo bờ biển, regalia nha trang cung cấp chỗ nghỉ hiện đại và trang nhã với wi-fi miễn phí trong toàn bộ khuôn viên. khách sạn này nằm cách trung tâm thuyền buồm việt nam khoảng 800 m trong khi du khách đi bộ 3 phút là đến bãi biển nha trang. phòng nghỉ tại đây có tầm nhìn ra thành phố biển, máy điều hòa, sàn gỗ parquet, tủ để quần áo, minibar, két an toàn trong phòng và tv màn hình phẳng. phòng tắm riêng đi kèm máy sấy tóc, dép và tiện nghi vòi sen. đội ngũ nhân viên tại quầy lễ tân 24 giờ của regalia nha trang có thể hỗ trợ du khách với các dịch vụ giữ hành lý, giặt là và tổ chức hội họp tiệc. các hoạt động tour du lịch và dịch vụ đưa đón sân bay cũng được cung cấp cho khách. du khách có thể sử dụng hồ bơi ngoài trời và khu vực bãi biển riêng với một khoản phụ phí. nhà hàng trong khuôn viên phục vụ tuyển chọn các món ăn ngon của địa phương và quốc tế. du khách có thể thưởng thức đồ uống sau bữa ăn tại quầy bar. sân bay quốc tế cam ranh cách đó 26 km.
#
# anh phuong hotel apartment (HotelId: 1062) (Score: 0.0000) (Semantic: 0.8310) (BM25: 0.0000) (Location: đà nẵng)
# tọa lạc tại thành phố đà nẵng, cách bãi biển mỹ khê chưa đầy 1 km, anh phuong hotel apartment cung cấp chỗ nghỉ bên bờ biển với vô số tiện nghi, chẳng hạn như nhà hàng và sân hiên. khách sạn 3 sao này có dịch vụ tiền sảnh và bàn đặt tour. chỗ nghỉ cung cấp dịch vụ lễ tân 24 giờ, dịch vụ phòng và dịch vụ thu đổi ngoại tệ cho khách. các căn tại đây được trang bị máy điều hòa, tv truyền hình vệ tinh màn hình phẳng, tủ lạnh, ấm đun nước, vòi xịt chậu rửa vệ sinh, dép đi trong phòng và bàn làm việc. các phòng được bố trí phòng tắm riêng, máy sấy tóc và ga trải giường. khách sạn phục vụ bữa sáng buffet hoặc bữa sáng à la carte. các điểm tham quan nổi tiếng gần anh phuong hotel apartment bao gồm cầu sông hàn, cầu khóa tình yêu và trung tâm thương mại indochina riverside. sân bay gần nhất là sân bay quốc tế đà nẵng, cách đó 5 km, và chỗ nghỉ cung cấp dịch vụ đưa đón sân bay với một khoản phụ phí.
#
# marina nha trang hotel (HotelId: 3667) (Score: 0.0000) (Semantic: 0.8308) (BM25: 0.0000) (Location: nha trang)
# tọa lạc tại thành phố nha trang, cách bãi biển nha trang 200 m, marina nha trang hotel có dịch vụ nhận phòng trả phòng cấp tốc, phòng nghỉ không gây dị ứng, vườn, wifi miễn phí trong toàn bộ khuôn viên và sân hiên. trong số các điểm tham quan nổi tiếng gần đó có quán sailing club, bảo tàng alexandre yersin và trung tâm mua sắm nha trang centre. chỗ nghỉ cung cấp dịch vụ lễ tân 24 giờ, bếp chung và tổ chức các tour du lịch cho khách. phòng nghỉ tại khách sạn được bố trí bàn làm việc, tv màn hình phẳng và phòng tắm riêng. phòng còn đi kèm máy điều hòa và tủ để quần áo. các điểm tham quan nổi tiếng gần chỗ nghỉ bao gồm quảng trường 2 4, tháp trầm hương và trung tâm thuyền buồm việt nam. sân bay gần nhất là sân bay quốc tế cam ranh, cách marina nha trang hotel 26 km, và chỗ nghỉ cung cấp dịch vụ đưa đón sân bay với một khoản phụ phí.
