# %%
pip install rank-bm25
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import pandas as pd
import numpy as np
from sklearn.preprocessing import normalize

# %%
df = pd.read_csv('dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3896 entries, 0 to 3895
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   HotelID       3896 non-null   int64
#  1   Name Hotel    3896 non-null   object
#  2   Address       3896 non-null   object
#  3   Location      3896 non-null   object
#  4   Descriptions  3896 non-null   object
#  5   Rating        3896 non-null   float64
#  6   IsEnglish     3896 non-null   bool
# dtypes: bool(1), float64(1), int64(1), object(4)
# memory usage: 186.6+ KB

# %%
df['Location'].unique()
# Out:
# array(['Phú Quốc', 'TP. Hồ Chí Minh', 'Đà Nẵng', 'Hà Nội', 'Nha Trang',
#        'Hội An', 'Đà Lạt', 'Sa Pa', 'Huế', 'Vũng Tàu'], dtype=object)

# %%
import re

def get_special_chars(df):
    # Gộp tất cả text trong dataframe (chỉ các cột kiểu object hoặc string)
    text_data = ' '.join(df.select_dtypes(include=['object']).astype(str).values.flatten())
    
    # Tìm tất cả ký tự không phải chữ, số hoặc khoảng trắng
    special_chars = re.findall(r'[^\w\s]', text_data)
    
    # Lấy unique và sắp xếp
    unique_chars = sorted(set(special_chars))
    
    print(f"🔎 Có {len(unique_chars)} ký tự đặc biệt khác nhau trong dữ liệu:\n")
    print(' '.join(unique_chars))
    return unique_chars

# %%
specials = get_special_chars(df)
# Out:
# 🔎 Có 37 ký tự đặc biệt khác nhau trong dữ liệu:
#
# ! " # % & ' ( ) * + , - . / : ; @ [ ] ` | ~ ­ ̀ ́ ̂ ̃ ̉ ̛ ̣ ​ – ’ “ ” ☆ ✩

# %%
import re
import unicodedata

# %%
def clean_vietnamese_text(text):
    if not isinstance(text, str):
        return ""
        
    text = unicodedata.normalize('NFC', text)
    
    text = text.lower()

    text = text.replace('%', ' phần trăm')
    
    text = re.sub(r'/\s*đêm', ' mỗi đêm', text, flags=re.IGNORECASE)
    text = re.sub(r"[^\w\s\-,.]", " ", text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# %%
text = "xin chàO"
print(clean_vietnamese_text(text))
# Out:
# xin chào

# %% [markdown]
# # Embedding với Sentence-BERT

# %% [markdown]
# # Load Sentence-BERT

# %%
from sentence_transformers import SentenceTransformer
sbert_model = SentenceTransformer('sentence-transformers/paraphrase-multilingual-mpnet-base-v2')
# sbert_model = SentenceTransformer('keepitreal/vietnamese-sbert')

# %% [markdown]
# # Ghép các trường lại thành 1 text để embedding

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3896 entries, 0 to 3895
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   HotelID       3896 non-null   int64
#  1   Name Hotel    3896 non-null   object
#  2   Address       3896 non-null   object
#  3   Location      3896 non-null   object
#  4   Descriptions  3896 non-null   object
#  5   Rating        3896 non-null   float64
#  6   IsEnglish     3896 non-null   bool
# dtypes: bool(1), float64(1), int64(1), object(4)
# memory usage: 186.6+ KB
# None

# %%
df.isnull().sum()
# Out:
# HotelID         0
# Name Hotel      0
# Address         0
# Location        0
# Descriptions    0
# Rating          0
# IsEnglish       0
# dtype: int64

# %%
df["TextForEmbedding"] = df["Descriptions"].apply(clean_vietnamese_text)

# %% [markdown]
# # Sinh embedding cho toàn bộ dataset

# %%
embeddings = sbert_model.encode(df["TextForEmbedding"].tolist(), batch_size=32, show_progress_bar=True)
embeddings = normalize(embeddings, axis=1)  # chuẩn hóa theo hàng
# Out:
# Batches:   0%|          | 0/122 [00:00<?, ?it/s]

# %%
print("Embedding shape:", embeddings.shape)
# Out:
# Embedding shape: (3896, 768)

# %%
print("✅ Embedding done!")
print("Kiểu dữ liệu:", type(embeddings))     # numpy.ndarray
print("Shape:", embeddings.shape)            # (số_samples, số_chiều) ví dụ (1000, 384)
print("Dtype:", embeddings.dtype)            # float32 hoặc float64
# Out:
# ✅ Embedding done!
# Kiểu dữ liệu: <class 'numpy.ndarray'>
# Shape: (3896, 768)
# Dtype: float32

# %%
norms = np.linalg.norm(embeddings, axis=1)
print(norms[:10])
# Out:
# [1.0000001  1.         0.99999994 1.0000001  1.0000001  1.
#  1.         0.99999994 1.         1.        ]

# %% [markdown]
# # Lưu vào Milvus

# %%
from pymilvus import FieldSchema, CollectionSchema, DataType, Collection, utility, connections

# %% [markdown]
# # Kết nối đến Milvus server

# %%
connections.connect(alias="default",host="localhost",port="19530")
collection_name = "hotels_collection_mpnet_base_v2"

# %% [markdown]
# # Tạo collection schema

# %%
# Kiểm tra xem collection đã tồn tại chưa
if utility.has_collection(collection_name):
    print(f"⚠️ Collection '{collection_name}' đã tồn tại, xóa và tạo mới lại...")
    utility.drop_collection(collection_name)

# Tạo mới collection
print(f"🚀 Tạo mới collection '{collection_name}'...")

fields = [
    FieldSchema(name="HotelID", dtype=DataType.INT64, is_primary=True, auto_id=False),
    FieldSchema(name="TextForEmbedding", dtype=DataType.FLOAT_VECTOR, dim=768),  # Sentence-BERT = 384, PhoBERT = 768
    FieldSchema(name="Location", dtype=DataType.VARCHAR, max_length=100), 
]

schema = CollectionSchema(fields=fields, description="Hotel dataset embeddings")

collection = Collection(name=collection_name, schema=schema)
print(f"✅ Collection '{collection_name}' đã được tạo mới thành công!")
# Out:
# 🚀 Tạo mới collection 'hotels_collection_mpnet_base_v2'...
# ✅ Collection 'hotels_collection_mpnet_base_v2' đã được tạo mới thành công!

# %% [markdown]
# # Chuẩn bị dữ liệu để insert

# %%
hotel_ids = df["HotelID"].astype(int).tolist()
locations = df["Location"].astype(str).str.strip().tolist()

# %%
print(type(embeddings))
print(type(hotel_ids))
print(type(locations))
# Out:
# <class 'numpy.ndarray'>
# <class 'list'>
# <class 'list'>

# %% [markdown]
# # Insert

# %%
collection.insert([
        hotel_ids,
        embeddings.tolist(),
        locations,
    ])

collection.flush()
print(f"📊 Số lượng bản ghi: {collection.num_entities}")
# Out:
# 📊 Số lượng bản ghi: 3896

# %%
index_params = {
    "index_type": "HNSW",
    "metric_type": "COSINE",
    "params": {"M": 8, "efConstruction": 64}
}
# Tạo index cho field vector
collection.release()
collection.drop_index()
collection.create_index(field_name="TextForEmbedding", index_params=index_params)
# Out:
# Status(code=0, message=)

# %%
collection = Collection(collection_name)
collection.load()

# %% [markdown]
# # demo

# %%
def clean_text_for_query(text):
    if not isinstance(text, str):
        return ""

    text = unicodedata.normalize('NFC', text)
    text = text.lower()

    text = re.sub(r"[^\w\s/\-]", " ", text)

    text = re.sub(r"\s+", " ", text).strip()

    return text

# %%
from underthesea import ner

def detect_city(query):
    cities = {
        "hồ chí minh": "Hồ Chí Minh",
        "tp hồ chí minh": "Hồ Chí Minh",
        "tp.hcm": "Hồ Chí Minh",
        "sài gòn": "Hồ Chí Minh",
        "hà nội": "Hà Nội",
        "đà nẵng": "Đà Nẵng",
        "phú quốc": "Phú Quốc",
        "nha trang": "Nha Trang",
        "hội an": "Hội An",
        "đà lạt": "Đà Lạt",
        "sa pa": "Sa Pa",
        "sapa": "Sa Pa",
        "huế": "Huế",
        "vũng tàu": "Vũng Tàu"
    }
    query_lower = query.lower()
    print(ner(query))
    # Rule-based
    for k, v in cities.items():
        if k in query_lower:
            return v
    
    # NER-based
    for word, _, _, tag in ner(query):
        if tag.endswith("LOC"):
            print(f'Địa danh nhận dạng: {word}')
            return word.title()
    
    return None

def prepare_query(query):
    city = detect_city(query)
    if city:
        semantic_query = query.lower().replace(city.lower(), "").strip()
        expr = f'Location like "%{city}%"'
    else:
        semantic_query = query
        expr = ""
    
    return semantic_query, expr

# %%
query = "homestay có hồ bơi gần biển Cà Mau"

semantic_query, expr = prepare_query(query)

semantic_query = clean_text_for_query(semantic_query)

query_emb = sbert_model.encode([query], normalize_embeddings=True)

search_params = {
    "metric_type": "COSINE",   # dùng độ tương đồng cosine
    "params": {"M": 8, "efConstruction": 64}
}

results = collection.search(
    data=query_emb,          # vector của query
    anns_field="TextForEmbedding",     # tên field chứa vector trong Milvus
    param=search_params,
    limit=10,                    # trả về top 5 kết quả gần nhất
    expr=expr,
    output_fields=["HotelID"]
)

result_data = []

for i, hits in enumerate(results):
    for hit in hits:
        result_data.append({
            "HotelID": hit.entity.get("HotelID"),
            "Similarity": hit.distance
        })

print("\n📄 Thông tin khách sạn tương ứng:\n")
print(f"Query: {query}\n")
for item in result_data:
    hotel_id = item["HotelID"]
    similarity = item["Similarity"]

    row = df[df["HotelID"] == hotel_id]

    if not row.empty:
        name = row.iloc[0].get("Name Hotel", "Không có tên")
        description = row.iloc[0].get("Descriptions", "Không có mô tả")
        print(f"🏨 {name} (ID: {hotel_id}, Similarity: {similarity:.4f})")
        print(f"   👉 {description}\n")
    else:
        print(f"⚠️ Không tìm thấy HotelID {hotel_id} trong CSV\n")
# Out:
# [('homestay', 'N', 'B-NP', 'O'), ('có', 'V', 'B-VP', 'O'), ('hồ', 'N', 'B-NP', 'O'), ('bơi', 'V', 'B-VP', 'O'), ('gần', 'A', 'B-AP', 'O'), ('biển', 'N', 'B-NP', 'O'), ('Cà Mau', 'Np', 'B-NP', 'B-LOC')]
# Địa danh nhận dạng: Cà Mau
#
# 📄 Thông tin khách sạn tương ứng:
#
# Query: homestay có hồ bơi gần biển Cà Mau

# %%
📄 Thông tin khách sạn tương ứng:

Query: homestay có hồ bơi gần biển ở Phú Quốc

🏨 Homestead Seaview Phú Quốc Hotel (ID: 251, Similarity: 0.7658)
   👉 Nằm trên đảo Phú Quốc, Homestead Seaview Phú Quốc Hotel có nhà hàng, hồ bơi ngoài trời, sảnh khách chung và khu vườn. Chỗ nghỉ này cũng có các phòng gia đình và sân hiên. Chỗ nghỉ cung cấp dịch vụ lễ tân 24 giờ, máy ATM và dịch vụ thu đổi ngoại tệ cho khách. Phòng nghỉ của khách sạn được trang bị máy điều hòa, TV màn hình phẳng với truyền hình vệ tinh, tủ lạnh, ấm đun nước, vòi sen, máy sấy tóc và bàn làm việc. Các phòng còn có tủ để quần áo và phòng tắm riêng. Homestead Seaview Phú Quốc Hotel phục vụ bữa sáng tự chọn hoặc bữa sáng à la carte. Đi xe đạp là hoạt động được ưa chuộng trong khu vực và du khách cũng có thể thuê xe hơi tại chỗ nghỉ. Homestead Seaview Phú Quốc Hotel nằm cách Chùa Sùng Hưng 4 km và Sòng bạc Corona 26 km.

🏨 HS Beach House Phu Quoc Island (ID: 3128, Similarity: 0.7649)
